# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"
query_url = f"{url}appid={weather_api_key}&units={unit}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=4168e3551f659b809998342357a60262&units=imperial&q=

# %%
response = requests.get(query_url+"toronto").json()
response
# Out:
# {'coord': {'lon': -79.42, 'lat': 43.7},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 42.51,
#   'feels_like': 31.26,
#   'temp_min': 41,
#   'temp_max': 44.01,
#   'pressure': 1009,
#   'humidity': 80},
#  'visibility': 14484,
#  'wind': {'speed': 14.99, 'deg': 210},
#  'clouds': {'all': 1},
#  'dt': 1587265996,
#  'sys': {'type': 1,
#   'id': 941,
#   'country': 'CA',
#   'sunrise': 1587205730,
#   'sunset': 1587254672},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
max_temp = response["main"]["temp_max"]
max_temp
# Out:
# 44.01

# %%
#API calls for each city in cities

city_data = []

for city in cities:
    
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    
    try: 
        
        weather_response = requests.get(query_url).json()
        
        city_name = weather_response["name"]
        city_cloudiness = weather_response["clouds"]
        country_name = weather_response["sys"]["country"]
        city_date = weather_response["dt"]
        city_humidity = weather_response["main"]["humidity"]
        city_lat = weather_response["coord"]["lat"]
        city_lon = weather_response["coord"]["lon"]
        max_temp = weather_response["main"]["temp_max"]
        wind_speed = weather_response["wind"]["speed"]
        
        
        city_data.append({"city_name":city_name,"city_cloudiness":city_cloudiness,"country_name":country_name,"city_date":city_date,"city_humidity":city_humidity,"city_lat":city_lat,"city_lon":city_lon,"max_temp":max_temp,"wind_speed":wind_speed})
        #weather_df = weather_df.append(cities_df)
        

        print(f"Retrieving Weather Informantion for {city}")
    except KeyError:
        print(f"{city} Information Missing")
# Out:
# Retrieving Weather Informantion for jiuquan
# Retrieving Weather Informantion for terney
# Retrieving Weather Informantion for la ciotat
# sentyabrskiy Information Missing
# Retrieving Weather Informantion for nouadhibou
# Retrieving Weather Informantion for albany
# Retrieving Weather Informantion for yamada
# Retrieving Weather Informantion for kramat
# Retrieving Weather Informantion for castro
# Retrieving Weather Informantion for gloversville
# Retrieving Weather Informantion for nizhniy kuranakh
# Retrieving Weather Informantion for bredasdorp
# Retrieving Weather Informantion for hermanus
# Retrieving Weather Informantion for kapaa
# Retrieving Weather Informantion for rikitea
# Retrieving Weather Informantion for longyearbyen
# Retrieving Weather Informantion for lugo
# Retrieving Weather Informantion for nikolskoye
# taolanaro Information Missing
# Retrieving Weather Informantion for avarua
# illoqqortoormiut Information Missing
# Retrieving Weather Informantion for svetlogorsk
# Retrieving Weather Informantion for tiksi
# Retrieving Weather Informantion for tetiyiv
# Retrieving Weather Informantion for kasongo-lunda
# Retrieving Weather Informantion for gat
# Retrieving Weather Informantion for ushuaia
# Retrieving Weather Informantion for tabas
# Retrieving Weather Informantion for kaka
# Retrieving Weather Informantion for ambon
# Retrieving Weather Informantion for chone
# Retrieving Weather Informantion for shelabolikha
# Retrieving Weather Informantion for zhigansk
# Retrieving Weather Informantion for ruvo di puglia
# Retrieving Weather Informantion for voh
# Retrieving Weather Informantion for atuona
# Retrieving Weather Informantion for khatanga
# Retrieving Weather Informantion for chokurdakh
# Retrieving Weather Informantion for arraial do cabo
# Retrieving Weather Informantion for itarema
# Retrieving Weather Informantion for hauterive
# Retrieving Weather Informantion for hobart
# Retrieving Weather Informantion for del rio
# Retrieving Weather Informantion for esperance
# Retrieving Weather Informantion for torbay
# Retrieving Weather Informantion for richards bay
# Retrieving Weather Informantion for kavaratti
# Retrieving Weather Informantion for sur
# barentsburg Information Missing
# Retrieving Weather Informantion for mount gambier
# Retrieving Weather Informantion for mataura
# Retrieving Weather Informantion for bandarbeyla
# Retrieving Weather Informantion for yellowknife
# Retrieving Weather Informantion for nakhon nayok
# Retrieving Weather Informantion for mexico
# Retrieving Weather Informantion for doba
# Retrieving Weather Informantion for vaini
# Retrieving Weather Informantion for oussouye
# Retrieving Weather Informantion for tuktoyaktuk
# Retrieving Weather Informantion for sangar
# Retrieving Weather Informantion for mahibadhoo
# Retrieving Weather Informantion for durant
# Retrieving Weather Informantion for kodiak
# Retrieving Weather Informantion for east london
# Retrieving Weather Informantion for saint-philippe
# Retrieving Weather Informantion for haines junction
# Retrieving Weather Informantion for barrow
# Retrieving Weather Informantion for longyan
# Retrieving Weather Informantion for ekhabi
# Retrieving Weather Informantion for bluff
# Retrieving Weather Informantion for mar del plata
# Retrieving Weather Informantion for yurty
# Retrieving Weather Informantion for vila velha
# Retrieving Weather Informantion for namibe
# Retrieving Weather Informantion for exaplatanos
# Retrieving Weather Informantion for tasiilaq
# Retrieving Weather Informantion for oksfjord
# Retrieving Weather Informantion for ostrovnoy
# Retrieving Weather Informantion for cabo san lucas
# Retrieving Weather Informantion for greenville
# Retrieving Weather Informantion for sorong
# Retrieving Weather Informantion for beringovskiy
# tsihombe Information Missing
# Retrieving Weather Informantion for qaanaaq
# Retrieving Weather Informantion for rjukan
# Retrieving Weather Informantion for sisimiut
# Retrieving Weather Informantion for busselton
# Retrieving Weather Informantion for codrington
# Retrieving Weather Informantion for paita
# Retrieving Weather Informantion for katsuura
# Retrieving Weather Informantion for altagracia de orituco
# Retrieving Weather Informantion for vysokogornyy
# Retrieving Weather Informantion for goundam
# Retrieving Weather Informantion for valparaiso
# Retrieving Weather Informantion for klaksvik
# Retrieving Weather Informantion for osecina
# Retrieving Weather Informantion for benin
# Retrieving Weather Informantion for becerril
# Retrieving Weather Informantion for rocky mountain house
# Retrieving Weather Informantion for iqaluit
# Retrieving Weather Informantion for punta arenas
# Retrieving Weather Informantion for kupang
# Retrieving Weather Informantion for honiara
# Retrieving Weather Informantion for hilo
# marcona Information Missing
# Retrieving Weather Informantion for qaqortoq
# Retrieving Weather Informantion for naze
# Retrieving Weather Informantion for camara de lobos
# Retrieving Weather Informantion for bengkulu
# Retrieving Weather Informantion for sitka
# Retrieving Weather Informantion for samarai
# Retrieving Weather Informantion for jamestown
# Retrieving Weather Informantion for dikson
# Retrieving Weather Informantion for grand gaube
# Retrieving Weather Informantion for san patricio
# Retrieving Weather Informantion for timberlake
# Retrieving Weather Informantion for hithadhoo
# Retrieving Weather Informantion for pahrump
# Retrieving Weather Informantion for tecpan
# Retrieving Weather Informantion for ponta do sol
# Retrieving Weather Informantion for longmont
# Retrieving Weather Informantion for pecos
# Retrieving Weather Informantion for cape town
# Retrieving Weather Informantion for belyy yar
# Retrieving Weather Informantion for carnarvon
# Retrieving Weather Informantion for tweed
# armacao dos buzios Information Missing
# Retrieving Weather Informantion for piacabucu
# Retrieving Weather Informantion for xuddur
# Retrieving Weather Informantion for chokwe
# tumannyy Information Missing
# Retrieving Weather Informantion for severo-kurilsk
# Retrieving Weather Informantion for geraldton
# Retrieving Weather Informantion for hofn
# Retrieving Weather Informantion for verkhoyansk
# Retrieving Weather Informantion for pisco
# Retrieving Weather Informantion for bathurst
# Retrieving Weather Informantion for pevek
# Retrieving Weather Informantion for tinskoy
# Retrieving Weather Informantion for bathsheba
# Retrieving Weather Informantion for cravo norte
# Retrieving Weather Informantion for lorengau
# Retrieving Weather Informantion for luebo
# Retrieving Weather Informantion for vardo
# Retrieving Weather Informantion for kodinsk
# Retrieving Weather Informantion for benghazi
# Retrieving Weather Informantion for lasa
# Retrieving Weather Informantion for ilulissat
# Retrieving Weather Informantion for mount isa
# Retrieving Weather Informantion for biak
# Retrieving Weather Informantion for nuevo progreso
# Retrieving Weather Informantion for saskylakh
# Retrieving Weather Informantion for skjervoy
# nizhneyansk Information Missing
# Retrieving Weather Informantion for rodino
# Retrieving Weather Informantion for marathon
# Retrieving Weather Informantion for kralendijk
# Retrieving Weather Informantion for vao
# Retrieving Weather Informantion for vanavara
# Retrieving Weather Informantion for verkhnevilyuysk
# Retrieving Weather Informantion for thompson
# belushya guba Information Missing
# Retrieving Weather Informantion for puerto ayora
# Retrieving Weather Informantion for tocopilla
# Retrieving Weather Informantion for faya
# Retrieving Weather Informantion for cerrito
# Retrieving Weather Informantion for kibre mengist
# Retrieving Weather Informantion for fairbanks
# Retrieving Weather Informantion for porto-vecchio
# Retrieving Weather Informantion for krasnyy chikoy
# Retrieving Weather Informantion for emerald
# Retrieving Weather Informantion for port alfred
# Retrieving Weather Informantion for yenagoa
# Retrieving Weather Informantion for upernavik
# Retrieving Weather Informantion for ardu
# Retrieving Weather Informantion for jaunpur
# Retrieving Weather Informantion for ullapool
# Retrieving Weather Informantion for santa rosa
# vaitupu Information Missing
# Retrieving Weather Informantion for dawei
# Retrieving Weather Informantion for kaitangata
# Retrieving Weather Informantion for saint george
# Retrieving Weather Informantion for khandyga
# Retrieving Weather Informantion for evensk
# Retrieving Weather Informantion for itabuna
# Retrieving Weather Informantion for ahuimanu
# Retrieving Weather Informantion for zhezkazgan
# grand river south east Information Missing
# palabuhanratu Information Missing
# Retrieving Weather Informantion for qasigiannguit
# Retrieving Weather Informantion for siloam springs
# Retrieving Weather Informantion for shiraz
# Retrieving Weather Informantion for doctor arroyo
# Retrieving Weather Informantion for benidorm
# Retrieving Weather Informantion for clyde river
# Retrieving Weather Informantion for souillac
# Retrieving Weather Informantion for cayenne
# Retrieving Weather Informantion for sagua la grande
# Retrieving Weather Informantion for jacqueville
# zhetybay Information Missing
# Retrieving Weather Informantion for touros
# saryshagan Information Missing
# Retrieving Weather Informantion for yangambi
# Retrieving Weather Informantion for inhambane
# Retrieving Weather Informantion for nalut
# Retrieving Weather Informantion for forssa
# thano bula khan Information Missing
# Retrieving Weather Informantion for victoria
# Retrieving Weather Informantion for bethel
# Retrieving Weather Informantion for port hardy
# Retrieving Weather Informantion for mehamn
# Retrieving Weather Informantion for barcelos
# Retrieving Weather Informantion for margate
# Retrieving Weather Informantion for lagoa
# Retrieving Weather Informantion for norman wells
# Retrieving Weather Informantion for pierre
# Retrieving Weather Informantion for sao filipe
# Retrieving Weather Informantion for lehututu
# Retrieving Weather Informantion for tarragona
# Retrieving Weather Informantion for llanes
# tokzar Information Missing
# Retrieving Weather Informantion for bubaque
# Retrieving Weather Informantion for kieta
# Retrieving Weather Informantion for pinar del rio
# Retrieving Weather Informantion for kununurra
# Retrieving Weather Informantion for iwanai
# Retrieving Weather Informantion for airai
# samalaeulu Information Missing
# Retrieving Weather Informantion for port elizabeth
# mys shmidta Information Missing
# Retrieving Weather Informantion for maceio
# balykshi Information Missing
# Retrieving Weather Informantion for concarneau
# Retrieving Weather Informantion for arani
# Retrieving Weather Informantion for kumbo
# Retrieving Weather Informantion for san cristobal
# Retrieving Weather Informantion for tautira
# Retrieving Weather Informantion for lalsk
# Retrieving Weather Informantion for ancud
# Retrieving Weather Informantion for synya
# Retrieving Weather Informantion for vondrozo
# Retrieving Weather Informantion for tahta
# Retrieving Weather Informantion for novopokrovka
# karaul Information Missing
# dianopolis Information Missing
# Retrieving Weather Informantion for vyazma
# Retrieving Weather Informantion for nanakuli
# barbar Information Missing
# Retrieving Weather Informantion for flinders
# alotau Information Missing
# Retrieving Weather Informantion for vaitape
# Retrieving Weather Informantion for requena
# Retrieving Weather Informantion for henties bay
# Retrieving Weather Informantion for bonthe
# Retrieving Weather Informantion for kruisfontein
# Retrieving Weather Informantion for lebu
# Retrieving Weather Informantion for ribeira grande
# Retrieving Weather Informantion for saint-francois
# Retrieving Weather Informantion for opuwo
# Retrieving Weather Informantion for salym
# Retrieving Weather Informantion for la ronge
# Retrieving Weather Informantion for straumen
# Retrieving Weather Informantion for dhidhdhoo
# Retrieving Weather Informantion for agidel
# Retrieving Weather Informantion for hasaki
# Retrieving Weather Informantion for port lincoln
# Retrieving Weather Informantion for sept-iles
# Retrieving Weather Informantion for lavrentiya
# amderma Information Missing
# Retrieving Weather Informantion for waikuku
# Retrieving Weather Informantion for constitucion
# Retrieving Weather Informantion for kloulklubed
# Retrieving Weather Informantion for khokhryaki
# Retrieving Weather Informantion for kosa
# Retrieving Weather Informantion for alugan
# Retrieving Weather Informantion for itupiranga
# Retrieving Weather Informantion for chernyshevskiy
# Retrieving Weather Informantion for kelheim
# Retrieving Weather Informantion for laguna
# Retrieving Weather Informantion for mezen
# mentok Information Missing
# Retrieving Weather Informantion for thunder bay
# Retrieving Weather Informantion for nokaneng
# Retrieving Weather Informantion for vagur
# Retrieving Weather Informantion for butaritari
# Retrieving Weather Informantion for khani
# Retrieving Weather Informantion for lata
# Retrieving Weather Informantion for aykhal
# Retrieving Weather Informantion for maningrida
# Retrieving Weather Informantion for pouembout
# Retrieving Weather Informantion for harper
# Retrieving Weather Informantion for humaita
# Retrieving Weather Informantion for cap malheureux
# Retrieving Weather Informantion for luderitz
# Retrieving Weather Informantion for qeshm
# Retrieving Weather Informantion for chuy
# Retrieving Weather Informantion for shelburne
# Retrieving Weather Informantion for provideniya
# Retrieving Weather Informantion for tarabuco
# Retrieving Weather Informantion for paralimni
# Retrieving Weather Informantion for pochutla
# Retrieving Weather Informantion for huari
# Retrieving Weather Informantion for jijiga
# Retrieving Weather Informantion for katobu
# Retrieving Weather Informantion for bambous virieux
# Retrieving Weather Informantion for bonavista
# Retrieving Weather Informantion for anadyr
# Retrieving Weather Informantion for jalu
# Retrieving Weather Informantion for georgetown
# Retrieving Weather Informantion for jingdezhen
# Retrieving Weather Informantion for hanzhong
# Retrieving Weather Informantion for korla
# Retrieving Weather Informantion for palmer
# Retrieving Weather Informantion for pacifica
# Retrieving Weather Informantion for atherton
# Retrieving Weather Informantion for husavik
# Retrieving Weather Informantion for sirjan
# Retrieving Weather Informantion for katherine
# Retrieving Weather Informantion for solnechnyy
# Retrieving Weather Informantion for sao jose da coroa grande
# Retrieving Weather Informantion for monrovia
# Retrieving Weather Informantion for coihaique
# Retrieving Weather Informantion for labuhan
# Retrieving Weather Informantion for plateros
# Retrieving Weather Informantion for khorixas
# Retrieving Weather Informantion for huarmey
# Retrieving Weather Informantion for new norfolk
# Retrieving Weather Informantion for warrnambool
# Retrieving Weather Informantion for teknaf
# Retrieving Weather Informantion for pacific grove
# Retrieving Weather Informantion for umba
# Retrieving Weather Informantion for newport
# Retrieving Weather Informantion for boende
# Retrieving Weather Informantion for mahebourg
# Retrieving Weather Informantion for odessa
# Retrieving Weather Informantion for cidreira
# Retrieving Weather Informantion for coahuayana
# kamenskoye Information Missing
# Retrieving Weather Informantion for monywa
# Retrieving Weather Informantion for bambanglipuro
# Retrieving Weather Informantion for vanimo
# tapaua Information Missing
# Retrieving Weather Informantion for pemba
# Retrieving Weather Informantion for pangai
# Retrieving Weather Informantion for jiaohe
# Retrieving Weather Informantion for north myrtle beach
# Retrieving Weather Informantion for brae
# Retrieving Weather Informantion for diffa
# Retrieving Weather Informantion for beohari
# Retrieving Weather Informantion for tacoronte
# Retrieving Weather Informantion for puerto del rosario
# Retrieving Weather Informantion for bereda
# Retrieving Weather Informantion for sevlievo
# Retrieving Weather Informantion for dourados
# Retrieving Weather Informantion for salalah
# Retrieving Weather Informantion for kargasok
# Retrieving Weather Informantion for visnes
# Retrieving Weather Informantion for manamadurai
# Retrieving Weather Informantion for togur
# Retrieving Weather Informantion for bassar
# warqla Information Missing
# Retrieving Weather Informantion for tabou
# Retrieving Weather Informantion for mercedes
# Retrieving Weather Informantion for aswan
# Retrieving Weather Informantion for monclova
# Retrieving Weather Informantion for amapa
# Retrieving Weather Informantion for urengoy
# Retrieving Weather Informantion for asyut
# Retrieving Weather Informantion for awbari
# Retrieving Weather Informantion for edd
# kytlym Information Missing
# Retrieving Weather Informantion for kahului
# Retrieving Weather Informantion for xinyang
# Retrieving Weather Informantion for watsa
# Retrieving Weather Informantion for shache
# Retrieving Weather Informantion for mwingi
# Retrieving Weather Informantion for quechultenango
# umzimvubu Information Missing
# Retrieving Weather Informantion for saldanha
# attawapiskat Information Missing
# Retrieving Weather Informantion for quelimane
# Retrieving Weather Informantion for apt
# Retrieving Weather Informantion for mayumba
# Retrieving Weather Informantion for asau
# Retrieving Weather Informantion for yerbogachen
# Retrieving Weather Informantion for nelson bay
# Retrieving Weather Informantion for golspie
# Retrieving Weather Informantion for hutchinson
# Retrieving Weather Informantion for sabha
# Retrieving Weather Informantion for itoman
# Retrieving Weather Informantion for guerrero negro
# Retrieving Weather Informantion for jacareacanga
# Retrieving Weather Informantion for lompoc
# toliary Information Missing
# Retrieving Weather Informantion for doha
# sahrak Information Missing
# Retrieving Weather Informantion for pasighat
# Retrieving Weather Informantion for bowen
# Retrieving Weather Informantion for montepuez
# Retrieving Weather Informantion for mangrol
# Retrieving Weather Informantion for progreso
# Retrieving Weather Informantion for aklavik
# Retrieving Weather Informantion for chara
# Retrieving Weather Informantion for mutsu
# Retrieving Weather Informantion for klyuchi
# Retrieving Weather Informantion for two hills
# Retrieving Weather Informantion for vestmannaeyjar
# Retrieving Weather Informantion for zharkent
# Retrieving Weather Informantion for pundaguitan
# Retrieving Weather Informantion for mahon
# Retrieving Weather Informantion for yeppoon
# Retrieving Weather Informantion for padang
# Retrieving Weather Informantion for tevaitoa
# Retrieving Weather Informantion for morgan city
# Retrieving Weather Informantion for namatanai
# Retrieving Weather Informantion for kwekwe
# Retrieving Weather Informantion for romny
# Retrieving Weather Informantion for teya
# tabiauea Information Missing
# Retrieving Weather Informantion for cotonou
# Retrieving Weather Informantion for belle fourche
# el balyana Information Missing
# Retrieving Weather Informantion for butka
# Retrieving Weather Informantion for razole
# Retrieving Weather Informantion for castlebar
# cockburn harbour Information Missing
# Retrieving Weather Informantion for baracoa
# Retrieving Weather Informantion for carauari
# xiongshi Information Missing
# Retrieving Weather Informantion for troitsko-pechorsk
# Retrieving Weather Informantion for dillon
# Retrieving Weather Informantion for broken hill
# Retrieving Weather Informantion for alenquer
# Retrieving Weather Informantion for presidente epitacio
# Retrieving Weather Informantion for amahai
# Retrieving Weather Informantion for lisakovsk
# Retrieving Weather Informantion for taoudenni
# Retrieving Weather Informantion for adrian
# Retrieving Weather Informantion for sulphur
# Retrieving Weather Informantion for ofaqim
# Retrieving Weather Informantion for avera
# Retrieving Weather Informantion for tulsipur
# Retrieving Weather Informantion for filingue
# Retrieving Weather Informantion for jertih
# Retrieving Weather Informantion for tukrah
# Retrieving Weather Informantion for santiago del estero
# Retrieving Weather Informantion for kharan
# Retrieving Weather Informantion for fort nelson
# Retrieving Weather Informantion for lac du bonnet
# one hundred mile house Information Missing
# Retrieving Weather Informantion for san jeronimo
# Retrieving Weather Informantion for abonnema
# Retrieving Weather Informantion for nobres
# Retrieving Weather Informantion for bealanana
# Retrieving Weather Informantion for atagay
# Retrieving Weather Informantion for port macquarie
# cheuskiny Information Missing
# Retrieving Weather Informantion for zdvinsk
# Retrieving Weather Informantion for rio gallegos
# Retrieving Weather Informantion for hambantota
# Retrieving Weather Informantion for kutum
# Retrieving Weather Informantion for fernley
# Retrieving Weather Informantion for north bend
# Retrieving Weather Informantion for keti bandar
# Retrieving Weather Informantion for muroto
# Retrieving Weather Informantion for raudeberg
# Retrieving Weather Informantion for comodoro rivadavia
# Retrieving Weather Informantion for talnakh
# Retrieving Weather Informantion for egvekinot
# Retrieving Weather Informantion for portland
# Retrieving Weather Informantion for gumdag
# Retrieving Weather Informantion for finschhafen
# Retrieving Weather Informantion for alice springs
# Retrieving Weather Informantion for noumea
# Retrieving Weather Informantion for willowmore
# Retrieving Weather Informantion for brewster
# Retrieving Weather Informantion for maradi
# Retrieving Weather Informantion for camacha
# Retrieving Weather Informantion for leshukonskoye
# Retrieving Weather Informantion for sorland
# Retrieving Weather Informantion for zhangjiakou
# Retrieving Weather Informantion for vilyuysk
# Retrieving Weather Informantion for abay
# Retrieving Weather Informantion for alakurtti
# Retrieving Weather Informantion for nizwa
# afmadu Information Missing
# Retrieving Weather Informantion for peleduy
# Retrieving Weather Informantion for boyolangu
# Retrieving Weather Informantion for nagtipunan
# ngukurr Information Missing
# wulanhaote Information Missing
# Retrieving Weather Informantion for shaowu
# Retrieving Weather Informantion for kirillov
# Retrieving Weather Informantion for kamenka
# Retrieving Weather Informantion for xingyi
# Retrieving Weather Informantion for tarata
# Retrieving Weather Informantion for tuatapere
# Retrieving Weather Informantion for galveston
# Retrieving Weather Informantion for zonguldak
# Retrieving Weather Informantion for san andres
# Retrieving Weather Informantion for dolgoye
# Retrieving Weather Informantion for sysert
# shchuchye Information Missing
# Retrieving Weather Informantion for san policarpo
# Retrieving Weather Informantion for barranco
# Retrieving Weather Informantion for los llanos de aridane
# Retrieving Weather Informantion for havre-saint-pierre
# Retrieving Weather Informantion for nizhniy odes
# Retrieving Weather Informantion for varzea da palma
# Retrieving Weather Informantion for berezovyy
# Retrieving Weather Informantion for surt
# Retrieving Weather Informantion for morwa
# bargal Information Missing
# Retrieving Weather Informantion for vostok
# Retrieving Weather Informantion for valreas
# Retrieving Weather Informantion for barinas
# Retrieving Weather Informantion for pinhao
# Retrieving Weather Informantion for rotifunk
# balimo Information Missing
# saleaula Information Missing
# Retrieving Weather Informantion for sioux lookout
# Retrieving Weather Informantion for yara
# Retrieving Weather Informantion for tuscaloosa
# Retrieving Weather Informantion for mantua
# Retrieving Weather Informantion for sheridan
# Retrieving Weather Informantion for tokur
# Retrieving Weather Informantion for mareeba
# Retrieving Weather Informantion for sinnamary
# Retrieving Weather Informantion for antalaha
# Retrieving Weather Informantion for garowe
# Retrieving Weather Informantion for nettuno
# Retrieving Weather Informantion for mtimbira
# Retrieving Weather Informantion for coquimbo
# Retrieving Weather Informantion for flin flon
# Retrieving Weather Informantion for nkongsamba
# Retrieving Weather Informantion for narsaq
# Retrieving Weather Informantion for tumut
# Retrieving Weather Informantion for alofi
# Retrieving Weather Informantion for belize
# Retrieving Weather Informantion for sao joao da barra
# Retrieving Weather Informantion for ilirska bistrica
# Retrieving Weather Informantion for hami
# Retrieving Weather Informantion for pitsunda
# Retrieving Weather Informantion for toguchin
# Retrieving Weather Informantion for loikaw
# Retrieving Weather Informantion for kysyl-syr
# Retrieving Weather Informantion for fortuna
# Retrieving Weather Informantion for kirakira
# Retrieving Weather Informantion for gondar
# Retrieving Weather Informantion for mandalgovi
# Retrieving Weather Informantion for new pitsligo
# bolshaya murta Information Missing
# Retrieving Weather Informantion for sokoto
# Retrieving Weather Informantion for wawa
# Retrieving Weather Informantion for grindavik
# Retrieving Weather Informantion for bidor
# Retrieving Weather Informantion for devarkonda
# Retrieving Weather Informantion for varzelandia
# Retrieving Weather Informantion for moyale
# Retrieving Weather Informantion for banloc
# Retrieving Weather Informantion for krasnoselkup
# Retrieving Weather Informantion for kavieng
# Retrieving Weather Informantion for vila
# Retrieving Weather Informantion for komsomolskiy
# Retrieving Weather Informantion for upington
# Retrieving Weather Informantion for lansdale
# Retrieving Weather Informantion for srednekolymsk
# Retrieving Weather Informantion for kachug
# Retrieving Weather Informantion for duluth
# Retrieving Weather Informantion for lukulu
# Retrieving Weather Informantion for bull savanna
# Retrieving Weather Informantion for ahipara
# Retrieving Weather Informantion for bowling green
# Retrieving Weather Informantion for mazagao
# Retrieving Weather Informantion for isangel
# Retrieving Weather Informantion for nome
# Retrieving Weather Informantion for las tunas
# bolungarvik Information Missing
# Retrieving Weather Informantion for lyudinovo
# Retrieving Weather Informantion for nanortalik
# Retrieving Weather Informantion for carutapera
# Retrieving Weather Informantion for aberdeen
# Retrieving Weather Informantion for beloha
# Retrieving Weather Informantion for baykit
# Retrieving Weather Informantion for caravelas
# Retrieving Weather Informantion for carmen
# Retrieving Weather Informantion for seymchan
# Retrieving Weather Informantion for tiznit
# Retrieving Weather Informantion for namuac
# Retrieving Weather Informantion for muros
# Retrieving Weather Informantion for faanui
# samusu Information Missing
# Retrieving Weather Informantion for salumbar
# Retrieving Weather Informantion for lhokseumawe
# Retrieving Weather Informantion for san miguel
# Retrieving Weather Informantion for lalibela
# Retrieving Weather Informantion for dromolaxia
# Retrieving Weather Informantion for ondjiva
# Retrieving Weather Informantion for sola
# Retrieving Weather Informantion for sechura
# Retrieving Weather Informantion for pringsewu
# Retrieving Weather Informantion for orange cove
# bo Information Missing
# Retrieving Weather Informantion for bemidji
# Retrieving Weather Informantion for matagami
# Retrieving Weather Informantion for puerto palomas
# Retrieving Weather Informantion for sayat
# Retrieving Weather Informantion for norrtalje
# Retrieving Weather Informantion for nurota
# Retrieving Weather Informantion for kharp
# Retrieving Weather Informantion for jega
# Retrieving Weather Informantion for kabalo
# Retrieving Weather Informantion for belaya gora
# Retrieving Weather Informantion for santa maria
# Retrieving Weather Informantion for mattru
# tarhunah Information Missing
# Retrieving Weather Informantion for neiafu
# ust-kamchatsk Information Missing
# Retrieving Weather Informantion for tilichiki
# Retrieving Weather Informantion for chapais
# burica Information Missing
# Retrieving Weather Informantion for calvinia
# Retrieving Weather Informantion for nouakchott
# Retrieving Weather Informantion for mpongwe
# Retrieving Weather Informantion for kiunga
# Retrieving Weather Informantion for burnie
# Retrieving Weather Informantion for tabuk
# Retrieving Weather Informantion for hailar

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#weather_df.to_csv("citiesweather.csv", index=False)

# %%
#weather_df = pd.DataFrame(columns = ["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"])
#weather_df = weather_df.append(city_data)
#weather_df
weather_df = pd.DataFrame({'count': city_data})#({
    #"City": city_name,
    #"Country": country_name,
    #"Cloudiness": cloudiness,
    #"Date": date,
    #"Humidity": humidity,
    #"Latitude": lat,
    #"Longitude": lng,
    #"Max Temperature": max_temp,
    #"Wind Speed": wind_speed
#})
weather_df
# Out:
#                                                  count
# 0    {'city_name': 'Jiuquan', 'city_cloudiness': {'...
# 1    {'city_name': 'Terney', 'city_cloudiness': {'a...
# 2    {'city_name': 'La Ciotat', 'city_cloudiness': ...
# 3    {'city_name': 'Nouadhibou', 'city_cloudiness':...
# 4    {'city_name': 'Albany', 'city_cloudiness': {'a...
# ..                                                 ...
# 569  {'city_name': 'Mpongwe', 'city_cloudiness': {'...
# 570  {'city_name': 'Kiunga', 'city_cloudiness': {'a...
# 571  {'city_name': 'Burnie', 'city_cloudiness': {'a...
# 572  {'city_name': 'Tabuk', 'city_cloudiness': {'al...
# 573  {'city_name': 'Hailar', 'city_cloudiness': {'a...
#
# [574 rows x 1 columns]

# %%
#weather_df = weather_df.append(city_data)
#weather_df.set_index("City",drop = True,inplace = True) 
#weather_df.reindex()
#weather_df

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_df["Lat"]
y_values = weather_df["Max Temp"]
plt.grid()
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs. Max Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for latitude vs humidity
x_values = weather_df["Lat"]
y_values = weather_df["Humidity"]
plt.grid()
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d0a3f3696fa6> in <module>
#       1 # Create a Scatter Plot for latitude vs humidity
# ----> 2 x_values = weather_df["Lat"]
#       3 y_values = weather_df["Humidity"]
#       4 plt.grid()
#       5 plt.scatter(x_values,y_values)
#
# NameError: name 'weather_df' is not defined

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values = weather_df["Lat"]
y_values = weather_df["Cloudiness"]
plt.grid()
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values = weather_df["Lat"]
y_values = weather_df["Wind Speed"]
plt.grid()
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (mph)')
plt.title("City Latitude vs. Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
